# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/img.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
h,s,v = cv2.split(hsv)

# %%
print(h)
# Out:
# [[152 152 152 ... 118 119 119]
#  [152 152 152 ... 118 118 119]
#  [152 152 152 ... 118 118 118]
#  ...
#  [120 120 120 ... 112 112 112]
#  [120 120 120 ... 112 112 112]
#  [120 120 120 ... 112 112 112]]

# %%
print(s)
# Out:
# [[ 83  83  85 ... 173 179 179]
#  [ 83  83  83 ... 173 173 179]
#  [ 85  83  83 ... 179 179 173]
#  ...
#  [133 135 135 ... 218 218 218]
#  [133 135 135 ... 218 218 218]
#  [135 135 135 ... 218 218 218]]

# %%
print(v)
# Out:
# [[52 52 51 ... 28 30 30]
#  [52 52 52 ... 28 28 30]
#  [51 52 52 ... 27 27 28]
#  ...
#  [50 49 49 ... 48 48 48]
#  [50 49 49 ... 48 48 48]
#  [49 49 49 ... 48 48 48]]

# %%
lower_h = 35
upper_h = 85

# %%
mask = cv2.inRange(h, lower_h, upper_h)

# %%
result = cv2.bitwise_and(img, img, mask=mask)

# %%
cv2.imwrite('result.jpg',result)
# Out:
# True

# %%
lower_h2 = 160
upper_h2 = 180

# %%
mask2 = cv2.inRange(h, lower_h2, upper_h2)

# %%
result2 = cv2.bitwise_and(img, img, mask=mask2)

# %%
cv2.imwrite('result2.jpg',result2)
# Out:
# True

# %%
lower_h3 = 100
upper_h3 = 130

# %%
mask3 = cv2.inRange(h, lower_h3, upper_h3)

# %%
result3 = cv2.bitwise_and(img, img, mask=mask3)

# %%
cv2.imwrite('result3.jpg',result3)
# Out:
# True

# %%
lower_h4 = 10
upper_h4 = 25

# %%
mask4 = cv2.inRange(h, lower_h4, upper_h4)

# %%
result4 = cv2.bitwise_and(img, img, mask=mask4)

# %%
cv2.imwrite('result4.jpg',result4)
# Out:
# True
